# %% [markdown]
# <a href="https://colab.research.google.com/github/Aakanksha-1208/Demo/blob/main/practice%20for%20exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  Write a Python statement that calculates and prints the number of  seconds in 7 hours, 21 minutes and 37 seconds.
hr= int(input("enter hrs"))
mn=int(input("enter min"))
sec=int(input("enter sec"))
print("result",(hr*3600+mn*60+sec))
# Out:
# enter hrs7
# enter min21
# enter sec0
# result 26460

# %%
import numpy as np
a=np.array([[1,2,3],[4,5,6]])
print(a.shape)
print(a.size)
print(type(a))
a.shape=(3,2)
print(a)
print(a.reshape(6,))
# Out:
# (2, 3)
# 6
# <class 'numpy.ndarray'>
# [[1 2]
#  [3 4]
#  [5 6]]
# [1 2 3 4 5 6]

# %%
import

# %%
# Write a Python expression that combines the string "Joe Warren is 52
# years old." from the string "Joe Warren" and the number 52 and then
# prints the result (Hint: Use the function str to convert the number into a
# string.)
a='joe warrwen'
b=52
print(a,'is',str(b))
# Out:
# joe warrwen is 52
